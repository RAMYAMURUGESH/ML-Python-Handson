# %%
import pandas as pd

# %% [markdown]
# ### Melt

# %%
df = pd.read_csv('life_expectancy_years.csv')

# %%
df.head()
df.shape #its in wide format 187 rows nd 302 columns
# Out:
# (187, 302)

# %%
df.columns
# Out:
# Index(['country', '1800', '1801', '1802', '1803', '1804', '1805', '1806',
#        '1807', '1808',
#        ...
#        '2091', '2092', '2093', '2094', '2095', '2096', '2097', '2098', '2099',
#        '2100'],
#       dtype='object', length=302)

# %%
melt_df = df.melt(id_vars='country',var_name='year',value_name='life_expectancy')
melt_df
# Out:
#            country  year  life_expectancy
# 0      Afghanistan  1800             28.2
# 1          Albania  1800             35.4
# 2          Algeria  1800             28.8
# 3          Andorra  1800              NaN
# 4           Angola  1800             27.0
# ...            ...   ...              ...
# 56282    Venezuela  2100             87.3
# 56283      Vietnam  2100             85.3
# 56284        Yemen  2100             78.4
# 56285       Zambia  2100             78.1
# 56286     Zimbabwe  2100             75.7
#
# [56287 rows x 3 columns]

# %% [markdown]
# ## pivot

# %%
pivot_df = melt_df.pivot(index='country',columns=['year'],values = 'life_expectancy')
pivot_df
# Out:
# year         1800  1801  1802  1803  1804  1805  1806  1807  1808  1809  ...  \
# country                                                                  ...
# Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1  28.1  28.1  ...
# Albania      35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  ...
# Algeria      28.8  28.8  28.8  28.8  28.8  28.8  28.8  28.8  28.8  28.8  ...
# Andorra       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Angola       27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  ...
# ...           ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# Venezuela    32.2  32.2  32.2  32.2  32.2  32.2  32.2  32.2  32.2  32.2  ...
# Vietnam      32.0  32.0  32.0  32.0  32.0  32.0  32.0  32.0  32.0  32.0  ...
# Yemen        23.4  23.4  23.4  23.4  23.4  23.4  23.4  23.4  23.4  23.4  ...
# Zambia       32.6  32.6  32.6  32.6  32.6  32.6  32.6  32.6  32.6  32.6  ...
# ...

# %% [markdown]
# ## Cross Tab function

# %%
new_df = pd.read_csv('employee.csv')
new_df.head()
#new_df.shape
pd.crosstab(new_df['Department'],new_df['EducationField'])
# Out:
# EducationField          Human Resources  Life Sciences  Marketing  Medical  \
# Department
# Human Resources                      27             16          0       13
# Research & Development                0            440          0      363
# Sales                                 0            150        159       88
#
# EducationField          Other  Technical Degree
# Department
# Human Resources             3                 4
# Research & Development     64                94
# Sales                      15                34

# %% [markdown]
# ## Bin:

# %%
pd.cut([1,8,2,3,5,4,6,7],3,labels=['low','mid','high'])
# Out:
# ['low', 'high', 'low', 'low', 'mid', 'mid', 'high', 'high']
# Categories (3, object): ['low' < 'mid' < 'high']

# %%
ab=pd.read_csv('employee.csv')
ab.head()
ab['DistanceFromHome'].value_counts()
# Out:
# 2     211
# 1     208
# 10     86
# 9      85
# 3      84
# 7      84
# 8      80
# 5      65
# 4      64
# 6      59
# 16     32
# 11     29
# 24     28
# 23     27
# 29     27
# 18     26
# 15     26
# 20     25
# 25     25
# 26     25
# 28     23
# 19     22
# 14     21
# 17     20
# 12     20
# 22     19
# 13     19
# 21     18
# 27     12
# Name: DistanceFromHome, dtype: int64

# %%
def modify(x):
    if x< 2:
        return 'near'
    elif x>2 and x<5:
        return 'far'
    else: 
        return 'very far'

# %%
ab['DistanceFromHome']= ab['DistanceFromHome'].apply(modify)
ab['DistanceFromHome'].value_counts()
# Out:
# very far    1114
# near         208
# far          148
# Name: DistanceFromHome, dtype: int64

# %%
ab['Age'].value_counts()
# Out:
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 38    58
# 33    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 24    26
# 25    26
# 47    24
# 49    24
# 55    22
# 53    19
# 48    19
# 51    19
# 52    18
# 54    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: Age, dtype: int64

# %%
def age_modify(x):
    if x <20:
        return 'teen'
    elif x>20 and x<40:
        return 'adult'
    elif x>40:
        return 'old age'

# %%
ab['Age_grp'] = ab['Age'].apply(age_modify)
ab['Age_grp'].value_counts()
# Out:
# adult      920
# old age    465
# teen        17
# Name: Age_grp, dtype: int64
